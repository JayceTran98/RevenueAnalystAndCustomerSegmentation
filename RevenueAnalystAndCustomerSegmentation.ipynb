# %%
import pandas as pd

# %% [markdown]
# # Read Datasets

# %% [markdown]
# customer

# %%
customer_info = pd.read_excel('E:/Data Analyst/Test_1/customers (UK).xlsx',index_col=0,sheet_name=0)

# %%
customer_info.head(5)
# Out:
#                 FirstName               LastName              Country  \
# ID
# 0      V0.296680287495188     L0.104646531512644          FR - France
# 1      D0.793097101838541   Law0.141693355411763        GER - Germany
# 2    Ker0.141418247925814    Ng0.753960335680345          FR - France
# 3    Fik0.950054552966336     F0.590961171612745  UK - United Kingdom
# 4   Iona0.294287981536498  Ison0.826191754811968           IT - Italy
#
#    DateJoined Gender   Birthday Newsletter
# ID
# 0  2015-12-18    NaN 1968-02-03          N
# 1  2015-12-21      M 2009-10-06          Y
# 2  2015-12-22      F 1990-08-04          Y
# 3  2015-12-22      M 1974-07-24          N
# 4  2015-12-22      M 1981-08-13          N

# %% [markdown]
# Items

# %%
items = pd.read_excel('E:/Data Analyst/Test_1/customers (UK).xlsx',index_col=0,sheet_name=1)

# %%
items.head(5)
# Out:
#                            Product             Brand  SellPrice  CostPrice
# ItemID
# 1       032irview0.686128260621012  Ki)D3jDmA,RIP68X        943        359
# 2       070ttream0.518887735674677  GO4582ey<S!+k1VE        717        207
# 3       070htream0.333307794468401  G.Kb^jz*soY!(-4Q        739        199
# 4       100Grseys0.271522111052549  Dr|vm[-5p~56Y\mk        532        262
# 5       100[nside0.645837365801341  Dr|vm[-5p~56Y\mk        593        392

# %% [markdown]
# Customer Transaction

# %%
customer_transaction = pd.read_excel('E:/Data Analyst/Test_1/customers (UK).xlsx',index_col=None,sheet_name=2)

# %%
customer_transaction
# Out:
#        OrderID  CustomerID  ItemID TransactionDate   Channel
# 0            0           0     352      2020-03-21  In Store
# 1            0           0    3433      2020-07-14  In Store
# 2            0           0   11162      2020-08-09  In Store
# 3            0           0   13011      2020-12-07  In Store
# 4            0           0   13885      2020-11-08  In Store
# ...        ...         ...     ...             ...       ...
# 25208     8361         769   10053      2020-12-19  In Store
# 25209     8361         769   13162      2020-02-04  In Store
# 25210     8362         769    8727      2020-11-18  In Store
# 25211     8362         769   13065      2020-05-11  In Store
# 25212     8362         769   13577      2020-06-05  In Store
#
# [25213 rows x 5 columns]

# %% [markdown]
# Traffic

# %%
file_names = [f'E:/Data Analyst/Test_1/2020_{i:02d}.xlsx' for i in range(1, 13)]
data_frames = []
for file_name in file_names:
    df = pd.read_excel(file_name)
    data_frames.append(df)
traffic = pd.concat(data_frames, ignore_index=True)

# %%
traffic.shape
# Out:
# (17889, 6)

# %%
traffic.dtypes
# Out:
# Page URL                          object
# users                            float64
# uniquePageviews                  float64
# pageviews                        float64
# Brand                             object
# Posted On (DD/MM/YYYY)    datetime64[ns]
# dtype: object

# %%
traffic.head()
# Out:
#                              Page URL   users  uniquePageviews  pageviews  \
# 0  /2020/1/032irview0.686128260621012  5669.2           5777.8     6286.4
# 1  /2020/1/070ttream0.518887735674677   359.8            370.4      403.4
# 2  /2020/1/070htream0.333307794468401   587.6            614.2      657.6
# 3  /2020/1/100Grseys0.271522111052549  1284.0           1308.6     1385.4
# 4  /2020/1/100[nside0.645837365801341  1846.0           1880.8     2025.0
#
#               Brand Posted On (DD/MM/YYYY)
# 0  Ki)D3jDmA,RIP68X    2020-01-10 16:56:13
# 1  GO4582ey<S!+k1VE    2020-01-10 05:04:35
# 2  G.Kb^jz*soY!(-4Q    2020-01-16 23:27:08
# 3  Dr|vm[-5p~56Y\mk    2020-01-17 12:32:24
# 4  Dr|vm[-5p~56Y\mk    2020-01-23 05:21:08

# %%
import re

# %%
traffic.iloc[0,0]
# Out:
# '/2020/1/032irview0.686128260621012'

# %%
traffic.iloc[1,0]
# Out:
# '/2020/1/070ttream0.518887735674677'

# %%
re.split('[/]',traffic.iloc[0,0])[-1]
# Out:
# '032irview0.686128260621012'

# %%
i = 0 
for i in range(len(traffic)):
    traffic.iloc[i,0] = re.split('[/]',traffic.iloc[i,0])[-1]

# %%
traffic.rename(columns= {'Page URL': 'Product'}, inplace= True)

# %%
traffic
# Out:
#                            Product   users  uniquePageviews  pageviews  \
# 0       032irview0.686128260621012  5669.2           5777.8     6286.4
# 1       070ttream0.518887735674677   359.8            370.4      403.4
# 2       070htream0.333307794468401   587.6            614.2      657.6
# 3       100Grseys0.271522111052549  1284.0           1308.6     1385.4
# 4       100[nside0.645837365801341  1846.0           1880.8     2025.0
# ...                            ...     ...              ...        ...
# 17884     yinfbowls0.6558670149224   130.0            133.2      142.2
# 17885  yosolease0.0455049365834417   314.6            325.6      365.2
# 17886   you^-info0.127669879156147  1419.6           1448.4     1615.8
# 17887   youe-info0.729842478879044   483.8            487.6      509.6
# 17888   zahJuseum0.120647638596675   823.2            837.6      886.8
#
#                         Brand Posted On (DD/MM/YYYY)
# 0            Ki)D3jDmA,RIP68X    2020-01-10 16:56:13
# 1            GO4582ey<S!+k1VE    2020-01-10 05:04:35
# 2            G.Kb^jz*soY!(-4Q    2020-01-16 23:27:08
# 3            Dr|vm[-5p~56Y\mk    2020-01-17 12:32:24
# 4            Dr|vm[-5p~56Y\mk    2020-01-23 05:21:08
# ...                       ...                    ...
# 17884  HoXbja)_x007f_qT:ESE8#    2020-12-01 04:55:35
# 17885        YoRQW7@*&5W+~4Y"    2020-12-03 15:25:00
# 17886        MouDd/fn,XEARhBp    2020-12-06 23:57:54
# 17887        yo4}AUKGso=,?!DX    2020-12-04 05:59:22
# 17888  Ch_x007f_w1fD(grL&W)5k    2020-12-05 23:49:29
#
# [17889 rows x 6 columns]

# %% [markdown]
# <b> Questions : <b>
# 1.	What is the impact of our website traffic on revenue?
# 2.	Which products get us pageviews and revenue?
# 3.	What customer segments are there?

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
##Check pageviews , users and unique pageviews

# %%
from matplotlib import rcParams

rcParams['figure.figsize'] = 15,8

# %%
sns.lineplot(data=traffic,x='Posted On (DD/MM/YYYY)',y='pageviews')
# Out:
# <Axes: xlabel='Posted On (DD/MM/YYYY)', ylabel='pageviews'>

# %%
sns.lineplot(data=traffic,x='Posted On (DD/MM/YYYY)',y='uniquePageviews')
# Out:
# <Axes: xlabel='Posted On (DD/MM/YYYY)', ylabel='uniquePageviews'>

# %%
sns.lineplot(data=traffic,x='Posted On (DD/MM/YYYY)',y='users')
# Out:
# <Axes: xlabel='Posted On (DD/MM/YYYY)', ylabel='users'>

# %% [markdown]
# It can be pageviews,uniquepageviews, and users access in traffic have similiar patterns => no need to differentiate, we can use any of them analyse traffic

# %%
#combined Data

# %%
result = customer_transaction.merge(customer_info,left_on='CustomerID',right_on='ID',how='inner').merge(items,left_on='ItemID',right_on='ItemID',how= 'inner')

# %%
result.columns
# Out:
# Index(['OrderID', 'CustomerID', 'ItemID', 'TransactionDate', 'Channel',
#        'FirstName', 'LastName', 'Country', 'DateJoined', 'Gender', 'Birthday',
#        'Newsletter', 'Product', 'Brand', 'SellPrice', 'CostPrice'],
#       dtype='object')

# %%
result.head()
# Out:
#    OrderID  CustomerID  ItemID TransactionDate   Channel  \
# 0        0           0     352      2020-03-21  In Store
# 1      637          57     352      2020-03-15  In Store
# 2        0           0    3433      2020-07-14  In Store
# 3     1840         167    3433      2020-05-16  In Store
# 4     3386         307    3433      2020-04-23  In Store
#
#                FirstName                LastName              Country  \
# 0     V0.296680287495188      L0.104646531512644          FR - France
# 1  Var0.0876970591979241  Bhan0.0592432181453122        GER - Germany
# 2     V0.296680287495188      L0.104646531512644          FR - France
# 3     Y0.694526245425698    Pur0.889218979929135  UK - United Kingdom
# 4   Moh0.478682882191102  Khair0.475794987205303          FR - France
#
#   DateJoined Gender   Birthday Newsletter                     Product  \
# 0 2015-12-18    NaN 1968-02-03          N  chrUrumor0.784919078952733
# 1 2016-02-02      F 1966-01-14          N  chrUrumor0.784919078952733
# 2 2015-12-18    NaN 1968-02-03          N  corGvideo0.268391324982493
# 3 2015-04-16      M 1972-03-23          Y  corGvideo0.268391324982493
# 4 2016-06-02    NaN 1989-05-04          Y  corGvideo0.268391324982493
#
#               Brand  SellPrice  CostPrice
# 0  MouDd/fn,XEARhBp        735        426
# 1  MouDd/fn,XEARhBp        735        426
# 2  muy(D#"d02`vwt_^        963        491
# 3  muy(D#"d02`vwt_^        963        491
# 4  muy(D#"d02`vwt_^        963        491

# %%
result.dtypes
# Out:
# OrderID                     int64
# CustomerID                  int64
# ItemID                      int64
# TransactionDate    datetime64[ns]
# Channel                    object
# FirstName                  object
# LastName                   object
# Country                    object
# DateJoined         datetime64[ns]
# Gender                     object
# Birthday           datetime64[ns]
# Newsletter                 object
# Product                    object
# Brand                      object
# SellPrice                   int64
# CostPrice                   int64
# dtype: object

# %% [markdown]
# summarize Data

# %%
transaction_summary = result.groupby(['TransactionDate','Channel']).agg(total_orders = ('OrderID','count'),total_customers = ('CustomerID','count'),total_items=('ItemID','count'))

# %%
transaction_summary.head(10)
# Out:
#                           total_orders  total_customers  total_items
# TransactionDate Channel
# 2020-01-01      In Store            30               30           30
#                 Online              36               36           36
# 2020-01-02      In Store            33               33           33
#                 Online              40               40           40
# 2020-01-03      In Store            46               46           46
#                 Online              36               36           36
# 2020-01-04      In Store            48               48           48
#                 Online              29               29           29
# 2020-01-05      In Store            38               38           38
#                 Online              37               37           37

# %%
transaction_summary.tail(10)
# Out:
#                           total_orders  total_customers  total_items
# TransactionDate Channel
# 2020-12-23      In Store            35               35           35
#                 Online              36               36           36
# 2020-12-24      In Store            35               35           35
#                 Online              24               24           24
# 2020-12-25      In Store            36               36           36
#                 Online              43               43           43
# 2020-12-26      In Store            28               28           28
#                 Online              41               41           41
# 2020-12-27      In Store            45               45           45
#                 Online              42               42           42

# %%
#check if data correct 1
result[result['TransactionDate']== '2020-01-01']
# Out:
#        OrderID  CustomerID  ItemID TransactionDate   Channel  \
# 6         4861         447    3433      2020-01-01    Online
# 552       1549         138    5214      2020-01-01    Online
# 816        117          10   14685      2020-01-01  In Store
# 967       6826         625   17259      2020-01-01  In Store
# 1621       237          21    7895      2020-01-01  In Store
# ...        ...         ...     ...             ...       ...
# 23654     6779         622     879      2020-01-01  In Store
# 23685     6922         634   10558      2020-01-01  In Store
# 23808     6893         632   15635      2020-01-01  In Store
# 24611     7653         706   16317      2020-01-01    Online
# 25105     8238         758    4664      2020-01-01    Online
#
#                     FirstName                LastName              Country  \
# 6       Yvon0.123331623956968    Tan0.662463855720801        GER - Germany
# 552    Munir0.543714510685389    Bah0.327151211426037          FR - France
# 816     Bill0.944762168333042      W0.775201627445077        GER - Germany
# 967       Yo0.956684467063237   Chan0.727240905288105          FR - France
# 1621      Ca0.719485458346245  Almad0.854027018192807           IT - Italy
# ...                       ...                     ...                  ...
# 23654     Ye0.638110229754228     Ka0.411880781632681          FR - France
# 23685   Say 0.850526343302479    Kon0.483043243017932          FR - France
# 23808    Ste0.833049318407553    Ong0.332374624629349          FR - France
# 24611      Y0.190402853759622      S0.253543080383404        GER - Germany
# 25105      Y0.044525328124793    Ad0.0973592950295998  UK - United Kingdom
#
#       DateJoined Gender   Birthday Newsletter                      Product  \
# 6     2015-05-14    NaN 2010-03-25          N   corGvideo0.268391324982493
# 552   2016-04-18    NaN 1997-01-04          N   cocilease0.908083727823501
# 816   2016-01-04      F 1981-06-16          N    ubel-info0.58211807634047
# 967   2016-09-13      M 1982-01-17          N   nikIusive0.939219885768624
# 1621  2016-01-11      M 1979-05-26          N   taiotflix0.106046169289087
# ...          ...    ...        ...        ...                          ...
# 23654 2016-09-13      F 1985-05-13          Y  maiz-week0.0608696585222449
# 23685 2016-09-13    NaN 1984-11-06          Y   jpeGtream0.351242818412425
# 23808 2016-09-13      F 1981-12-06          N   mattailer0.701516578394223
# 24611 2016-09-05    NaN 2005-05-22          N   youRvideo0.801750471025558
# 25105 2015-05-25      F 1965-11-01          N   manoe-jdm0.855542939951595
#
#                   Brand  SellPrice  CostPrice
# 6      muy(D#"d02`vwt_^        963        491
# 552    AtxysEOSb~n37M^u        880        111
# 816    Ub&H{u8HeJ1Fh-).        758        248
# 967    NiPea$n|Eu@<@>'L       1094        144
# 1621   Ne=:l%8x/P<_.o/U        241         53
# ...                 ...        ...        ...
# 23654  PaEhhlt"U6s0p86y        247         54
# 23685  Deg%MX`9@78X?;8        528        407
# 23808  DC)DYqe!L)1<vPy&       1274         67
# 24611  muy(D#"d02`vwt_^       1058        179
# 25105  To|)mWQ"c59)2m#s        400        280
#
# [66 rows x 16 columns]

# %%
#check if data correct 2
result[result['TransactionDate']== '2020-12-27']
# Out:
#        OrderID  CustomerID  ItemID TransactionDate   Channel  \
# 915       8161         751   17419      2020-12-27    Online
# 1529      7117         654    5281      2020-12-27  In Store
# 2564      2857         258   13151      2020-12-27    Online
# 3367      5883         539    7307      2020-12-27  In Store
# 3794      1395         126   13585      2020-12-27    Online
# ...        ...         ...     ...             ...       ...
# 24815     7876         725    7531      2020-12-27    Online
# 24854     7910         728    3355      2020-12-27  In Store
# 24879     7936         731    7546      2020-12-27  In Store
# 24940     8258         760    4256      2020-12-27  In Store
# 25030     8145         750   16560      2020-12-27  In Store
#
#                     FirstName               LastName        Country  \
# 915        V0.296680287495188   Pan0.346033355426464  GER - Germany
# 1529    Wong0.810790234168482     S0.778561743794072  GER - Germany
# 2564      YS0.722933239396374     Y0.748969118135783    FR - France
# 3367      Ro0.125394122544836      H0.18251437449923  GER - Germany
# 3794    Test0.619791443082027  Test0.390581071558474  GER - Germany
# ...                       ...                    ...            ...
# 24815      W0.726490821196358     C0.294395678101911  GER - Germany
# 24854   Sze 0.330830024542068  Chan0.727240905288105  GER - Germany
# 24879  There0.261416426223307     K0.775057321737499  GER - Germany
# 24940     We0.401622991634416    Fo0.730822068803465  GER - Germany
# 25030    Yew0.250320656872678    F0.0709113848720752  GER - Germany
#
#       DateJoined Gender   Birthday Newsletter                     Product  \
# 915   2016-09-05    NaN 1982-06-19          Y  pokp-info0.768922082161193
# 1529  2016-09-15      M 1995-12-17          Y  dipsvideo0.475299891637777
# 2564  2016-06-02    NaN 1978-11-02          N  you\video0.285562395386008
# 3367  2016-09-05      F 2000-03-15          Y  marOlease0.795639929116617
# 3794  2015-03-02      M 2010-04-25          N  ea-Tailer0.893321005190528
# ...          ...    ...        ...        ...                         ...
# 24815 2016-09-05    NaN 2008-06-10          Y  niknpment0.262669342113911
# 24854 2016-09-05    NaN 1971-01-07          Y  breNation0.930179039582495
# 24879 2016-09-05    NaN 1999-03-06          Y  nikk7-1020.416240807262137
# 24940 2016-09-05    NaN 1972-06-09          N  strgkbook0.927590158985239
# 25030 2016-09-05      F 1971-01-13          Y  bitP-info0.464074782291613
#
#                   Brand  SellPrice  CostPrice
# 915    Co$mc>0IB/4/.-q        344        403
# 1529   Di>F/&\dpnsv;i33        732        367
# 2564   muy(D#"d02`vwt_^        958        465
# 3367   Ac8IJsKH,4xtY.Tk       1195        444
# 3794   EA)aXNV1HcF_AR-B        746         48
# ...                 ...        ...        ...
# 24815  NiPea$n|Eu@<@>'L       1143        475
# 24854  Br|d#9"fZwR|o^i~        103         88
# 24879  NiPea$n|Eu@<@>'L        450        225
# 24940  St1&Y+@PDjz0@~E        555        462
# 25030  BoJmlDA"J>GDp<X=        258         45
#
# [87 rows x 16 columns]

# %% [markdown]
# => Results are corrected

# %%
transaction_summary= transaction_summary.reset_index(level=0)

# %%
transaction_summary.reset_index(inplace=True)

# %%
transaction_summary
# Out:
#       Channel TransactionDate  total_orders  total_customers  total_items
# 0    In Store      2020-01-01            30               30           30
# 1      Online      2020-01-01            36               36           36
# 2    In Store      2020-01-02            33               33           33
# 3      Online      2020-01-02            40               40           40
# 4    In Store      2020-01-03            46               46           46
# ..        ...             ...           ...              ...          ...
# 643    Online      2020-12-25            43               43           43
# 644  In Store      2020-12-26            28               28           28
# 645    Online      2020-12-26            41               41           41
# 646  In Store      2020-12-27            45               45           45
# 647    Online      2020-12-27            42               42           42
#
# [648 rows x 5 columns]

# %%
transaction_summary[transaction_summary['Channel']== 'Online'].describe()
# Out:
#        total_orders  total_customers  total_items
# count    324.000000       324.000000   324.000000
# mean      38.793210        38.793210    38.793210
# std        6.310134         6.310134     6.310134
# min       22.000000        22.000000    22.000000
# 25%       34.000000        34.000000    34.000000
# 50%       39.000000        39.000000    39.000000
# 75%       43.000000        43.000000    43.000000
# max       58.000000        58.000000    58.000000

# %%
transaction_summary[transaction_summary['Channel']== 'In Store'].describe()
# Out:
#        total_orders  total_customers  total_items
# count    324.000000       324.000000   324.000000
# mean      39.024691        39.024691    39.024691
# std        6.549124         6.549124     6.549124
# min       19.000000        19.000000    19.000000
# 25%       35.000000        35.000000    35.000000
# 50%       39.000000        39.000000    39.000000
# 75%       43.000000        43.000000    43.000000
# max       60.000000        60.000000    60.000000

# %%
sns.lineplot(data=transaction_summary,x='TransactionDate',y='total_orders',hue='Channel')
# Out:
# <Axes: xlabel='TransactionDate', ylabel='total_orders'>

# %% [markdown]
# => There are no significant difference between sales In Store and Online

# %%
result['revenue'] = result['SellPrice']-result['CostPrice']

# %%
revenue_details = result.groupby(['TransactionDate','Channel']).agg(total_revenue = ('revenue','sum'))

# %%
revenue_details = revenue_details.reset_index(level=0)

# %%
revenue_details.reset_index(inplace=True)

# %%
revenue_details
# Out:
#       Channel TransactionDate  total_revenue
# 0    In Store      2020-01-01          16038
# 1      Online      2020-01-01          23275
# 2    In Store      2020-01-02          16644
# 3      Online      2020-01-02          22223
# 4    In Store      2020-01-03          24388
# ..        ...             ...            ...
# 643    Online      2020-12-25          20501
# 644  In Store      2020-12-26          15248
# 645    Online      2020-12-26          21642
# 646  In Store      2020-12-27          25504
# 647    Online      2020-12-27          22519
#
# [648 rows x 3 columns]

# %%
revenue_details[revenue_details['Channel']== 'In Store'].describe()
# Out:
#        total_revenue
# count     324.000000
# mean    21064.543210
# std      4136.207078
# min      6603.000000
# 25%     18338.500000
# 50%     20925.500000
# 75%     23853.000000
# max     35710.000000

# %%
revenue_details[revenue_details['Channel']== 'Online'].describe()
# Out:
#        total_revenue
# count     324.000000
# mean    21038.929012
# std      4070.871630
# min     10515.000000
# 25%     18441.250000
# 50%     20903.500000
# 75%     23599.750000
# max     33250.000000

# %%
revenue = result.groupby('TransactionDate').agg(total_revenue = ('revenue','sum'))

# %%
revenue.reset_index(inplace=True)

# %%
revenue
# Out:
#     TransactionDate  total_revenue
# 0        2020-01-01          39313
# 1        2020-01-02          38867
# 2        2020-01-03          44887
# 3        2020-01-04          45062
# 4        2020-01-05          39821
# ..              ...            ...
# 319      2020-12-23          42167
# 320      2020-12-24          29895
# 321      2020-12-25          42494
# 322      2020-12-26          36890
# 323      2020-12-27          48023
#
# [324 rows x 2 columns]

# %% [markdown]
# <b> Total Revenue by Date <b>

# %%
sns.lineplot(data=revenue,x='TransactionDate',y='total_revenue')
# Out:
# <Axes: xlabel='TransactionDate', ylabel='total_revenue'>

# %%
sns.lineplot(data=revenue_details,x='TransactionDate',y='total_revenue',hue='Channel')
# Out:
# <Axes: xlabel='TransactionDate', ylabel='total_revenue'>

# %%
traffic['Date'] = traffic['Posted On (DD/MM/YYYY)'].dt.date

# %%
traffic = traffic.sort_values('Date')

# %%
traffic
# Out:
#                           Product   users  uniquePageviews  pageviews  \
# 1213   poryn-9920.309751616966229  9866.6          10010.4    10795.6
# 602    hent-info0.385052771142595   194.6            197.6      210.2
# 49      a-qXailer0.39660536369098  3450.4           3497.6     3705.8
# 1320   saiLvideo0.515764406060948   163.4            171.2      188.4
# 626    hum]lease0.864468117834064   514.0            521.2      549.0
# ...                           ...     ...              ...        ...
# 17448  airQ-info0.171240252405071  2830.0           2909.0     3207.8
# 17772  ricOlease0.528185410307296   166.8            170.0      182.6
# 17430  343mlease0.794977730394533   268.2            272.4      294.4
# 17855  twiO-word0.109741844099603   813.2            831.6      889.8
# 17817  supB-info0.696374523177401   325.8            335.0      359.6
#
#                         Brand Posted On (DD/MM/YYYY)        Date
# 1213         PoAqnL=>P9Qb"ZUa    2020-01-01 15:30:15  2020-01-01
# 602          HeIS-rF\J%qN[?/l    2020-01-01 23:31:54  2020-01-01
# 49           MouDd/fn,XEARhBp    2020-01-01 10:16:03  2020-01-01
# 1320         VipZx1>S^s?}%X(}    2020-01-01 23:29:34  2020-01-01
# 626          Nif@Q!eOOz|,#i'+    2020-01-01 23:36:51  2020-01-01
# ...                       ...                    ...         ...
# 17448  Jo?$J}r__x007f_"0#/!m:    2020-12-09 10:52:52  2020-12-09
# 17772  Jex`2_x007f_KBPsj*XwM_    2020-12-09 15:15:39  2020-12-09
# 17430        HaOe|~p9UZ^#pGl)    2020-12-09 02:22:29  2020-12-09
# 17855        Mc&v?E*9%}~WP@rD    2020-12-09 00:30:57  2020-12-09
# 17817        Su9JFbYW(9lrbYkD    2020-12-09 04:37:54  2020-12-09
#
# [17889 rows x 7 columns]

# %%
traffic_summary = traffic.groupby('Date').agg(users = ('users','sum'),uniquePageviews = ('uniquePageviews','sum'),pageviews = ('pageviews','sum'))

# %%
traffic_summary.reset_index(inplace=True)

# %%
traffic_summary
# Out:
#            Date     users  uniquePageviews  pageviews
# 0    2020-01-01   63755.4          64814.8    70353.6
# 1    2020-01-02  111861.4         113640.0   122557.8
# 2    2020-01-03   63749.8          65175.4    71058.0
# 3    2020-01-04   13946.0          14274.6    15349.6
# 4    2020-01-05   47065.0          47856.6    51438.2
# ..          ...       ...              ...        ...
# 338  2020-12-05   23906.0          24678.8    27024.6
# 339  2020-12-06   25892.8          26517.0    28433.4
# 340  2020-12-07   95081.8          97565.0   105456.0
# 341  2020-12-08  100577.0         105419.6   150902.2
# 342  2020-12-09   48557.4          50617.8    73336.2
#
# [343 rows x 4 columns]

# %% [markdown]
# <b>Total Traffic by date (pageviews) <b>

# %%
sns.lineplot(data=traffic_summary,x='Date',y='pageviews')
# Out:
# <Axes: xlabel='Date', ylabel='pageviews'>

# %%
revenue
# Out:
#     TransactionDate  total_revenue
# 0        2020-01-01          39313
# 1        2020-01-02          38867
# 2        2020-01-03          44887
# 3        2020-01-04          45062
# 4        2020-01-05          39821
# ..              ...            ...
# 319      2020-12-23          42167
# 320      2020-12-24          29895
# 321      2020-12-25          42494
# 322      2020-12-26          36890
# 323      2020-12-27          48023
#
# [324 rows x 2 columns]

# %%
revenue.dtypes
# Out:
# TransactionDate    datetime64[ns]
# total_revenue               int64
# dtype: object

# %%
traffic_summary
# Out:
#            Date     users  uniquePageviews  pageviews
# 0    2020-01-01   63755.4          64814.8    70353.6
# 1    2020-01-02  111861.4         113640.0   122557.8
# 2    2020-01-03   63749.8          65175.4    71058.0
# 3    2020-01-04   13946.0          14274.6    15349.6
# 4    2020-01-05   47065.0          47856.6    51438.2
# ..          ...       ...              ...        ...
# 338  2020-12-05   23906.0          24678.8    27024.6
# 339  2020-12-06   25892.8          26517.0    28433.4
# 340  2020-12-07   95081.8          97565.0   105456.0
# 341  2020-12-08  100577.0         105419.6   150902.2
# 342  2020-12-09   48557.4          50617.8    73336.2
#
# [343 rows x 4 columns]

# %%
traffic_summary['Date']= pd.to_datetime(traffic_summary['Date'])

# %%
traffic_summary.dtypes
# Out:
# Date               datetime64[ns]
# users                     float64
# uniquePageviews           float64
# pageviews                 float64
# dtype: object

# %%
traffic_summary.describe()
# Out:
#                users  uniquePageviews      pageviews
# count     343.000000       343.000000     343.000000
# mean    72781.425073     74803.171429   83078.834402
# std     38840.942231     40240.498438   47452.526424
# min     12086.400000     12343.200000   13315.800000
# 25%     41195.000000     42069.200000   45158.100000
# 50%     74229.800000     75627.000000   82663.400000
# 75%     95049.600000     97523.600000  105455.500000
# max    348640.400000    358664.200000  379756.800000

# %%
relations = revenue.merge(traffic_summary,left_on= 'TransactionDate',right_on= 'Date',how= 'inner').drop(columns ='Date')

# %%
relations
# Out:
#     TransactionDate  total_revenue     users  uniquePageviews  pageviews
# 0        2020-01-01          39313   63755.4          64814.8    70353.6
# 1        2020-01-02          38867  111861.4         113640.0   122557.8
# 2        2020-01-03          44887   63749.8          65175.4    71058.0
# 3        2020-01-04          45062   13946.0          14274.6    15349.6
# 4        2020-01-05          39821   47065.0          47856.6    51438.2
# ..              ...            ...       ...              ...        ...
# 300      2020-12-05          38178   23906.0          24678.8    27024.6
# 301      2020-12-06          32850   25892.8          26517.0    28433.4
# 302      2020-12-07          43533   95081.8          97565.0   105456.0
# 303      2020-12-08          46231  100577.0         105419.6   150902.2
# 304      2020-12-09          58925   48557.4          50617.8    73336.2
#
# [305 rows x 5 columns]

# %%
plt.scatter(relations['total_revenue'], relations['pageviews'])

# %%
plt.scatter(relations['total_revenue'], relations['users'])

# %%
relations['total_revenue'].corr(relations['pageviews'])
# Out:
# 0.07223295608010234

# %%
relations['total_revenue'].corr(relations['users'])
# Out:
# 0.07432403688407599

# %% [markdown]
# As we can see , there are no significant relationship between revenue and pageviews <br>
# => There are no significant impact between website traffic and revenue

# %%
result.tail(10)
# Out:
#        OrderID  CustomerID  ItemID TransactionDate   Channel  \
# 25203     8354         769    2110      2020-06-23  In Store
# 25204     8354         769    8700      2020-07-26  In Store
# 25205     8355         769    9751      2020-09-04  In Store
# 25206     8357         769    6657      2020-02-01    Online
# 25207     8358         769     914      2020-08-07  In Store
# 25208     8358         769   15836      2020-10-14  In Store
# 25209     8359         769    5847      2020-05-27    Online
# 25210     8362         769    8727      2020-11-18  In Store
# 25211     8362         769   13065      2020-05-11  In Store
# 25212     8362         769   13577      2020-06-05  In Store
#
#                  FirstName               LastName        Country DateJoined  \
# 25203  Yu0.868816854574661  Tuck0.670377392941702  GER - Germany 2016-09-05
# 25204  Yu0.868816854574661  Tuck0.670377392941702  GER - Germany 2016-09-05
# 25205  Yu0.868816854574661  Tuck0.670377392941702  GER - Germany 2016-09-05
# 25206  Yu0.868816854574661  Tuck0.670377392941702  GER - Germany 2016-09-05
# 25207  Yu0.868816854574661  Tuck0.670377392941702  GER - Germany 2016-09-05
# 25208  Yu0.868816854574661  Tuck0.670377392941702  GER - Germany 2016-09-05
# 25209  Yu0.868816854574661  Tuck0.670377392941702  GER - Germany 2016-09-05
# 25210  Yu0.868816854574661  Tuck0.670377392941702  GER - Germany 2016-09-05
# 25211  Yu0.868816854574661  Tuck0.670377392941702  GER - Germany 2016-09-05
# 25212  Yu0.868816854574661  Tuck0.670377392941702  GER - Germany 2016-09-05
#
#       Gender   Birthday Newsletter                       Product  \
# 25203      M 1990-05-23          Y    fka]ntine0.968577157714527
# 25204      M 1990-05-23          Y  forwgster0.00559100847796445
# 25205      M 1990-05-23          Y   virHj-set0.0295798825877848
# 25206      M 1990-05-23          Y     bodXation0.21911482156486
# 25207      M 1990-05-23          Y    merm-20200.223442049235318
# 25208      M 1990-05-23          Y    offqrview0.479298708383635
# 25209      M 1990-05-23          Y   nnactream0.0225798759099386
# 25210      M 1990-05-23          Y   g-snation0.0993461911005428
# 25211      M 1990-05-23          Y    undflease0.156012002899051
# 25212      M 1990-05-23          Y    dreg-loan0.957624173047318
#
#                   Brand  SellPrice  CostPrice  revenue
# 25203  FK{9.G1N&tPjkT?H        902         53      849
# 25204  FonU]s_e#15bXv*5        524        446       78
# 25205  GenUf@rQF8bi;Vq`       1112        426      686
# 25206  Bo}~4E4|Yt]}.eQ2        512        170      342
# 25207  Me}_[8WU)-c8ZZ5C       1051        329      722
# 25208  Vi1[g>Gp]F76d[;'        197        146       51
# 25209  NN`~?6^%O*KH,[S        833        280      553
# 25210  WaQqK)2JxI(=dac=        205         66      139
# 25211  Uny~Y,~<rTC^J6py       1012        272      740
# 25212  St(~u}!m<6Hj^Mv8       1244        387      857

# %%
items_revenue = result.groupby(['Brand','Product']).agg(total_revenue = ('revenue','sum'),total_orders = ('OrderID','count'),total_customers = ('CustomerID','count'),total_items= ('ItemID','count'))

# %%
items_revenue.sort_values('total_revenue',ascending=False).head(10)
# Out:
#                                              total_revenue  total_orders  \
# Brand            Product
# Il^(xPdB:S`#irqz hypsrview0.321288570724117           9072             9
# Ac8IJsKH,4xtY.Tk audE-info0.884915261087885           7665             7
# Relp\+KJ?D,cWw0P reeelease0.452821711209563           7119             7
# YMbpE$ev3qMx-h*E ymc_orson0.319251813809483           6810             6
# Sa?9zXUH5iJbuE'S samLement0.78565851365938            6762             6
# Hau8L!>mriLOop havAkbook0.460615356421681           6648             6
# Mi+QB'FqF;cGT)Y' theftream0.650769488105747           6575             5
# Relp\+KJ?D,cWw0P bbcF-date0.977769785530841           6455             5
# Ka>n{\}.q.~P&*Ao takgeveal0.557457939403364           6454             7
# PoAqnL=>P9Qb"ZUa poryn-9920.309751616966229           6315             5
#
#                                              total_customers  total_items
# Brand            Product
# Il^(xPdB:S`#irqz hypsrview0.321288570724117                9            9
# Ac8IJsKH,4xtY.Tk audE-info0.884915261087885                7            7
# Relp\+KJ?D,cWw0P reeelease0.452821711209563                7            7
# YMbpE$ev3qMx-h*E ymc_orson0.319251813809483                6            6
# Sa?9zXUH5iJbuE'S samLement0.78565851365938                 6            6
# Hau8L!>mriLOop havAkbook0.460615356421681                6            6
# Mi+QB'FqF;cGT)Y' theftream0.650769488105747                5            5
# Relp\+KJ?D,cWw0P bbcF-date0.977769785530841                5            5
# Ka>n{\}.q.~P&*Ao takgeveal0.557457939403364                7            7
# PoAqnL=>P9Qb"ZUa poryn-9920.309751616966229                5            5

# %%
items_revenue.sort_values('total_revenue',ascending=False).tail(10)
# Out:
#                                              total_revenue  total_orders  \
# Brand            Product
# Ince!T,;eW/4o\eg elon-info0.723888211415764           -474             3
# MC"-Vh8dUu|\\8J4 mcm_paign0.340258951857064           -525             5
# PabvI!bnb537$Ia" palnknits0.549002484211691           -543             3
# Ca<WQ$*V1bo%{vw| calBailer0.786336704118578           -550             2
# Di2&2w%Z2_S.BSoW magE-info0.345398543510131           -555             5
# Nes[8ukT8KBR8yVs news-info0.461919646457777           -600             4
# GeYut1YKw^'`D:p& getz-info0.411473609280735           -663             3
# muy(D#"d02`vwt_^ masGtream0.361077670662163           -699             3
# frUg|tv^erM5|zD sup]-list0.688799445411248           -717             3
# AiCF)Msmll)aU2_C stojo-unc0.375966250890653           -735             3
#
#                                              total_customers  total_items
# Brand            Product
# Ince!T,;eW/4o\eg elon-info0.723888211415764                3            3
# MC"-Vh8dUu|\\8J4 mcm_paign0.340258951857064                5            5
# PabvI!bnb537$Ia" palnknits0.549002484211691                3            3
# Ca<WQ$*V1bo%{vw| calBailer0.786336704118578                2            2
# Di2&2w%Z2_S.BSoW magE-info0.345398543510131                5            5
# Nes[8ukT8KBR8yVs news-info0.461919646457777                4            4
# GeYut1YKw^'`D:p& getz-info0.411473609280735                3            3
# muy(D#"d02`vwt_^ masGtream0.361077670662163                3            3
# frUg|tv^erM5|zD sup]-list0.688799445411248                3            3
# AiCF)Msmll)aU2_C stojo-unc0.375966250890653                3            3

# %%
items_revenue['total_revenue'].describe()
# Out:
# count    13542.000000
# mean      1007.349358
# std        914.677915
# min       -735.000000
# 25%        351.000000
# 50%        758.500000
# 75%       1370.000000
# max       9072.000000
# Name: total_revenue, dtype: float64

# %%
sns.boxplot(data=items_revenue,y='total_revenue')
# Out:
# <Axes: ylabel='total_revenue'>

# %%
items_revenue['Ranking']=items_revenue.apply(lambda x:'Low' if (x['total_revenue'] < 351)
                                                else ('Medium' if(x['total_revenue'] > 351 and x['total_revenue'] <758)
                                                else ('High'if (x['total_revenue'] > 758 and x['total_revenue'] < 1370)
                                                else 'Cash Cow')),axis= 1)

# %%
items_revenue[items_revenue['Ranking']=='Cash Cow'].sort_values('total_revenue',ascending=False).head(10)
# Out:
#                                              total_revenue  total_orders  \
# Brand            Product
# Il^(xPdB:S`#irqz hypsrview0.321288570724117           9072             9
# Ac8IJsKH,4xtY.Tk audE-info0.884915261087885           7665             7
# Relp\+KJ?D,cWw0P reeelease0.452821711209563           7119             7
# YMbpE$ev3qMx-h*E ymc_orson0.319251813809483           6810             6
# Sa?9zXUH5iJbuE'S samLement0.78565851365938            6762             6
# Hau8L!>mriLOop havAkbook0.460615356421681           6648             6
# Mi+QB'FqF;cGT)Y' theftream0.650769488105747           6575             5
# Relp\+KJ?D,cWw0P bbcF-date0.977769785530841           6455             5
# Ka>n{\}.q.~P&*Ao takgeveal0.557457939403364           6454             7
# PoAqnL=>P9Qb"ZUa poryn-9920.309751616966229           6315             5
#
#                                              total_customers  total_items  \
# Brand            Product
# Il^(xPdB:S`#irqz hypsrview0.321288570724117                9            9
# Ac8IJsKH,4xtY.Tk audE-info0.884915261087885                7            7
# Relp\+KJ?D,cWw0P reeelease0.452821711209563                7            7
# YMbpE$ev3qMx-h*E ymc_orson0.319251813809483                6            6
# Sa?9zXUH5iJbuE'S samLement0.78565851365938                 6            6
# Hau8L!>mriLOop havAkbook0.460615356421681                6            6
# Mi+QB'FqF;cGT)Y' theftream0.650769488105747                5            5
# Relp\+KJ?D,cWw0P bbcF-date0.977769785530841                5            5
# Ka>n{\}.q.~P&*Ao takgeveal0.557457939403364                7            7
# PoAqnL=>P9Qb"ZUa poryn-9920.309751616966229                5            5
#
#                                               Ranking
# Brand            Product
# Il^(xPdB:S`#irqz hypsrview0.321288570724117  Cash Cow
# Ac8IJsKH,4xtY.Tk audE-info0.884915261087885  Cash Cow
# Relp\+KJ?D,cWw0P reeelease0.452821711209563  Cash Cow
# YMbpE$ev3qMx-h*E ymc_orson0.319251813809483  Cash Cow
# Sa?9zXUH5iJbuE'S samLement0.78565851365938   Cash Cow
# Hau8L!>mriLOop havAkbook0.460615356421681  Cash Cow
# Mi+QB'FqF;cGT)Y' theftream0.650769488105747  Cash Cow
# Relp\+KJ?D,cWw0P bbcF-date0.977769785530841  Cash Cow
# Ka>n{\}.q.~P&*Ao takgeveal0.557457939403364  Cash Cow
# PoAqnL=>P9Qb"ZUa poryn-9920.309751616966229  Cash Cow

# %%
items_revenue[items_revenue['Ranking']== 'High'].sort_values('total_revenue',ascending=False).head(10)
# Out:
#                                               total_revenue  total_orders  \
# Brand            Product
# To{he^Wb.xvE#E}, staGlease0.916078853074645            1368             2
# BaM;gk|):j72N5{Y herE-20200.902652638353496            1368             3
# AtxysEOSb~n37M^u atmg-dark0.396417857871779            1368             3
# ad(;%f6iD'}9EHD[ reur-info0.0188811898574208           1368             1
# VipZx1>S^s?}%X(} teegvideo0.244126960533096            1366             2
# NiPea$n|Eu@<@>'L nikI-info0.612281394057791            1366             2
# Nes[8ukT8KBR8yVs n-hD-info0.180931441326865            1366             2
# Co$mc>0IB/4/.-q joyKclock0.0391613485949879           1366             2
# G-kn)K:(0XgD4qKk g-e`video0.137680953806272            1365             3
# BrN0@Jy{m$S{F'VO fooYvogue0.295261735745936            1365             3
#
#                                               total_customers  total_items  \
# Brand            Product
# To{he^Wb.xvE#E}, staGlease0.916078853074645                 2            2
# BaM;gk|):j72N5{Y herE-20200.902652638353496                 3            3
# AtxysEOSb~n37M^u atmg-dark0.396417857871779                 3            3
# ad(;%f6iD'}9EHD[ reur-info0.0188811898574208                1            1
# VipZx1>S^s?}%X(} teegvideo0.244126960533096                 2            2
# NiPea$n|Eu@<@>'L nikI-info0.612281394057791                 2            2
# Nes[8ukT8KBR8yVs n-hD-info0.180931441326865                 2            2
# Co$mc>0IB/4/.-q joyKclock0.0391613485949879                2            2
# G-kn)K:(0XgD4qKk g-e`video0.137680953806272                 3            3
# BrN0@Jy{m$S{F'VO fooYvogue0.295261735745936                 3            3
#
#                                              Ranking
# Brand            Product
# To{he^Wb.xvE#E}, staGlease0.916078853074645     High
# BaM;gk|):j72N5{Y herE-20200.902652638353496     High
# AtxysEOSb~n37M^u atmg-dark0.396417857871779     High
# ad(;%f6iD'}9EHD[ reur-info0.0188811898574208    High
# VipZx1>S^s?}%X(} teegvideo0.244126960533096     High
# NiPea$n|Eu@<@>'L nikI-info0.612281394057791     High
# Nes[8ukT8KBR8yVs n-hD-info0.180931441326865     High
# Co$mc>0IB/4/.-q joyKclock0.0391613485949879    High
# G-kn)K:(0XgD4qKk g-e`video0.137680953806272     High
# BrN0@Jy{m$S{F'VO fooYvogue0.295261735745936     High

# %%
items_revenue[items_revenue['Ranking'] == 'Medium'].sort_values('total_revenue',ascending=False).head(10)
# Out:
#                                               total_revenue  total_orders  \
# Brand            Product
# AdvwQxp]rN7CyxfH higNition0.83715494038496              757             1
# St>A1OvTgWhGk)0g lmcukbook0.476022847133936             757             1
# NiPea$n|Eu@<@>'L str`-info0.399397632414945             757             1
# Te0.)edhJTDlX%vE tesW-rise0.0752505392986521            757             1
# Mo,o.]e?.?N$}7So riccation0.0714964660937099            757             1
# Nes[8ukT8KBR8yVs newT-info0.144643724138913             757             1
# JoOzDd8Gf_aF2O<l artm-info0.893918031716357             757             1
# Ac8IJsKH,4xtY.Tk 101klease0.455008653652148             756             1
# VipZx1>S^s?}%X(} fisrvideo0.307766970170861             756             2
# Je_Z'it%PFr{_>r? almY-wise0.270101236955298             756             1
#
#                                               total_customers  total_items  \
# Brand            Product
# AdvwQxp]rN7CyxfH higNition0.83715494038496                  1            1
# St>A1OvTgWhGk)0g lmcukbook0.476022847133936                 1            1
# NiPea$n|Eu@<@>'L str`-info0.399397632414945                 1            1
# Te0.)edhJTDlX%vE tesW-rise0.0752505392986521                1            1
# Mo,o.]e?.?N$}7So riccation0.0714964660937099                1            1
# Nes[8ukT8KBR8yVs newT-info0.144643724138913                 1            1
# JoOzDd8Gf_aF2O<l artm-info0.893918031716357                 1            1
# Ac8IJsKH,4xtY.Tk 101klease0.455008653652148                 1            1
# VipZx1>S^s?}%X(} fisrvideo0.307766970170861                 2            2
# Je_Z'it%PFr{_>r? almY-wise0.270101236955298                 1            1
#
#                                              Ranking
# Brand            Product
# AdvwQxp]rN7CyxfH higNition0.83715494038496    Medium
# St>A1OvTgWhGk)0g lmcukbook0.476022847133936   Medium
# NiPea$n|Eu@<@>'L str`-info0.399397632414945   Medium
# Te0.)edhJTDlX%vE tesW-rise0.0752505392986521  Medium
# Mo,o.]e?.?N$}7So riccation0.0714964660937099  Medium
# Nes[8ukT8KBR8yVs newT-info0.144643724138913   Medium
# JoOzDd8Gf_aF2O<l artm-info0.893918031716357   Medium
# Ac8IJsKH,4xtY.Tk 101klease0.455008653652148   Medium
# VipZx1>S^s?}%X(} fisrvideo0.307766970170861   Medium
# Je_Z'it%PFr{_>r? almY-wise0.270101236955298   Medium

# %%
items_revenue[items_revenue['Ranking'] == 'Low'].sort_values('total_revenue',ascending=False).head(10)
# Out:
#                                               total_revenue  total_orders  \
# Brand            Product
# Me)=j(k#pe;yd0FE medWlease0.0473696204393813            350             2
# Vi_,vgbn\`ou7z[! virm-info0.682418757259103             350             2
# Lo`oaX!JFEv=Gucq lou[splay0.581376993338478             350             2
# Ince!T,;eW/4o\eg gunLrview0.201622898858429             350             1
# NE@.lc)SIA@G14=X neilction0.301533281903651             350             1
# Vi11{p=-f3r(_&-N vitvutler0.934886282982291             350             2
# Fuf&'}D{xF~nDqcm maryiture0.867279476488076             350             2
# PaEhhlt"U6s0p86y maiJswear0.39212870660039              350             1
# TN~2zg4|A-y2vih~ snofailer0.725276401832327             350             1
# Ma/J0*ar?Rce}C(@ macNideos0.505902918232793             349             1
#
#                                               total_customers  total_items  \
# Brand            Product
# Me)=j(k#pe;yd0FE medWlease0.0473696204393813                2            2
# Vi_,vgbn\`ou7z[! virm-info0.682418757259103                 2            2
# Lo`oaX!JFEv=Gucq lou[splay0.581376993338478                 2            2
# Ince!T,;eW/4o\eg gunLrview0.201622898858429                 1            1
# NE@.lc)SIA@G14=X neilction0.301533281903651                 1            1
# Vi11{p=-f3r(_&-N vitvutler0.934886282982291                 2            2
# Fuf&'}D{xF~nDqcm maryiture0.867279476488076                 2            2
# PaEhhlt"U6s0p86y maiJswear0.39212870660039                  1            1
# TN~2zg4|A-y2vih~ snofailer0.725276401832327                 1            1
# Ma/J0*ar?Rce}C(@ macNideos0.505902918232793                 1            1
#
#                                              Ranking
# Brand            Product
# Me)=j(k#pe;yd0FE medWlease0.0473696204393813     Low
# Vi_,vgbn\`ou7z[! virm-info0.682418757259103      Low
# Lo`oaX!JFEv=Gucq lou[splay0.581376993338478      Low
# Ince!T,;eW/4o\eg gunLrview0.201622898858429      Low
# NE@.lc)SIA@G14=X neilction0.301533281903651      Low
# Vi11{p=-f3r(_&-N vitvutler0.934886282982291      Low
# Fuf&'}D{xF~nDqcm maryiture0.867279476488076      Low
# PaEhhlt"U6s0p86y maiJswear0.39212870660039       Low
# TN~2zg4|A-y2vih~ snofailer0.725276401832327      Low
# Ma/J0*ar?Rce}C(@ macNideos0.505902918232793      Low

# %%
items_revenue.sort_values('total_orders',ascending=False).head(10)
# Out:
#                                              total_revenue  total_orders  \
# Brand            Product
# Il^(xPdB:S`#irqz hypsrview0.321288570724117           9072             9
# ThgQNp?BtjmQ3c&> thentream0.732405168500389            903             7
# Ka>n{\}.q.~P&*Ao takgeveal0.557457939403364           6454             7
# Relp\+KJ?D,cWw0P reeelease0.452821711209563           7119             7
# PrK4o:,^(M"#Y|yJ nikj-info0.857493166032007           4753             7
# JeRYij%"t1Z-Z8uz teaaessor0.958723169349025            658             7
# Ac8IJsKH,4xtY.Tk audE-info0.884915261087885           7665             7
# Kaemj:V;+O6cOHt6 kawDstore0.464236227679679           3038             7
# Anm-M&BQR&6@{+j6 youSobile0.567509538286633           1548             6
# Relp\+KJ?D,cWw0P kicu-date0.740642873207985           3036             6
#
#                                              total_customers  total_items  \
# Brand            Product
# Il^(xPdB:S`#irqz hypsrview0.321288570724117                9            9
# ThgQNp?BtjmQ3c&> thentream0.732405168500389                7            7
# Ka>n{\}.q.~P&*Ao takgeveal0.557457939403364                7            7
# Relp\+KJ?D,cWw0P reeelease0.452821711209563                7            7
# PrK4o:,^(M"#Y|yJ nikj-info0.857493166032007                7            7
# JeRYij%"t1Z-Z8uz teaaessor0.958723169349025                7            7
# Ac8IJsKH,4xtY.Tk audE-info0.884915261087885                7            7
# Kaemj:V;+O6cOHt6 kawDstore0.464236227679679                7            7
# Anm-M&BQR&6@{+j6 youSobile0.567509538286633                6            6
# Relp\+KJ?D,cWw0P kicu-date0.740642873207985                6            6
#
#                                               Ranking
# Brand            Product
# Il^(xPdB:S`#irqz hypsrview0.321288570724117  Cash Cow
# ThgQNp?BtjmQ3c&> thentream0.732405168500389      High
# Ka>n{\}.q.~P&*Ao takgeveal0.557457939403364  Cash Cow
# Relp\+KJ?D,cWw0P reeelease0.452821711209563  Cash Cow
# PrK4o:,^(M"#Y|yJ nikj-info0.857493166032007  Cash Cow
# JeRYij%"t1Z-Z8uz teaaessor0.958723169349025    Medium
# Ac8IJsKH,4xtY.Tk audE-info0.884915261087885  Cash Cow
# Kaemj:V;+O6cOHt6 kawDstore0.464236227679679  Cash Cow
# Anm-M&BQR&6@{+j6 youSobile0.567509538286633  Cash Cow
# Relp\+KJ?D,cWw0P kicu-date0.740642873207985  Cash Cow

# %%
items_revenue.sort_values('total_orders',ascending=False).tail(10)
# Out:
#                                               total_revenue  total_orders  \
# Brand            Product
# Eb@*a7)nz-LaZaH! ebaxpicks0.0962410021889232            284             1
# NiPea$n|Eu@<@>'L nikp-info0.938396305656351             969             1
# Eb@*a7)nz-LaZaH! ebay-news0.46158595355439              172             1
# NiPea$n|Eu@<@>'L nikp-info0.687953309587529             386             1
#                  nikp-info0.40776251224919             1200             1
# EcFVMmG[En=fe'Jm eckvunway0.0201431029243903            415             1
# EdLkeO%w](R~Za7T myd[anger0.185175614387759             314             1
# NiPea$n|Eu@<@>'L nikolease0.522717681429552              83             1
#                  nikolease0.152433481787525             345             1
# Ét2:1))2]qB2`9;^ etujation0.0817298363167827            870             1
#
#                                               total_customers  total_items  \
# Brand            Product
# Eb@*a7)nz-LaZaH! ebaxpicks0.0962410021889232                1            1
# NiPea$n|Eu@<@>'L nikp-info0.938396305656351                 1            1
# Eb@*a7)nz-LaZaH! ebay-news0.46158595355439                  1            1
# NiPea$n|Eu@<@>'L nikp-info0.687953309587529                 1            1
#                  nikp-info0.40776251224919                  1            1
# EcFVMmG[En=fe'Jm eckvunway0.0201431029243903                1            1
# EdLkeO%w](R~Za7T myd[anger0.185175614387759                 1            1
# NiPea$n|Eu@<@>'L nikolease0.522717681429552                 1            1
#                  nikolease0.152433481787525                 1            1
# Ét2:1))2]qB2`9;^ etujation0.0817298363167827                1            1
#
#                                              Ranking
# Brand            Product
# Eb@*a7)nz-LaZaH! ebaxpicks0.0962410021889232     Low
# NiPea$n|Eu@<@>'L nikp-info0.938396305656351     High
# Eb@*a7)nz-LaZaH! ebay-news0.46158595355439       Low
# NiPea$n|Eu@<@>'L nikp-info0.687953309587529   Medium
#                  nikp-info0.40776251224919      High
# EcFVMmG[En=fe'Jm eckvunway0.0201431029243903  Medium
# EdLkeO%w](R~Za7T myd[anger0.185175614387759      Low
# NiPea$n|Eu@<@>'L nikolease0.522717681429552      Low
#                  nikolease0.152433481787525      Low
# Ét2:1))2]qB2`9;^ etujation0.0817298363167827    High

# %%
items_revenue.sort_values('total_customers',ascending=False).head(10)
# Out:
#                                              total_revenue  total_orders  \
# Brand            Product
# Il^(xPdB:S`#irqz hypsrview0.321288570724117           9072             9
# ThgQNp?BtjmQ3c&> thentream0.732405168500389            903             7
# Ka>n{\}.q.~P&*Ao takgeveal0.557457939403364           6454             7
# Relp\+KJ?D,cWw0P reeelease0.452821711209563           7119             7
# PrK4o:,^(M"#Y|yJ nikj-info0.857493166032007           4753             7
# JeRYij%"t1Z-Z8uz teaaessor0.958723169349025            658             7
# Ac8IJsKH,4xtY.Tk audE-info0.884915261087885           7665             7
# Kaemj:V;+O6cOHt6 kawDstore0.464236227679679           3038             7
# Anm-M&BQR&6@{+j6 youSobile0.567509538286633           1548             6
# Relp\+KJ?D,cWw0P kicu-date0.740642873207985           3036             6
#
#                                              total_customers  total_items  \
# Brand            Product
# Il^(xPdB:S`#irqz hypsrview0.321288570724117                9            9
# ThgQNp?BtjmQ3c&> thentream0.732405168500389                7            7
# Ka>n{\}.q.~P&*Ao takgeveal0.557457939403364                7            7
# Relp\+KJ?D,cWw0P reeelease0.452821711209563                7            7
# PrK4o:,^(M"#Y|yJ nikj-info0.857493166032007                7            7
# JeRYij%"t1Z-Z8uz teaaessor0.958723169349025                7            7
# Ac8IJsKH,4xtY.Tk audE-info0.884915261087885                7            7
# Kaemj:V;+O6cOHt6 kawDstore0.464236227679679                7            7
# Anm-M&BQR&6@{+j6 youSobile0.567509538286633                6            6
# Relp\+KJ?D,cWw0P kicu-date0.740642873207985                6            6
#
#                                               Ranking
# Brand            Product
# Il^(xPdB:S`#irqz hypsrview0.321288570724117  Cash Cow
# ThgQNp?BtjmQ3c&> thentream0.732405168500389      High
# Ka>n{\}.q.~P&*Ao takgeveal0.557457939403364  Cash Cow
# Relp\+KJ?D,cWw0P reeelease0.452821711209563  Cash Cow
# PrK4o:,^(M"#Y|yJ nikj-info0.857493166032007  Cash Cow
# JeRYij%"t1Z-Z8uz teaaessor0.958723169349025    Medium
# Ac8IJsKH,4xtY.Tk audE-info0.884915261087885  Cash Cow
# Kaemj:V;+O6cOHt6 kawDstore0.464236227679679  Cash Cow
# Anm-M&BQR&6@{+j6 youSobile0.567509538286633  Cash Cow
# Relp\+KJ?D,cWw0P kicu-date0.740642873207985  Cash Cow

# %%
items_revenue.sort_values('total_customers',ascending=False).tail(10)
# Out:
#                                               total_revenue  total_orders  \
# Brand            Product
# Eb@*a7)nz-LaZaH! ebaxpicks0.0962410021889232            284             1
# NiPea$n|Eu@<@>'L nikp-info0.938396305656351             969             1
# Eb@*a7)nz-LaZaH! ebay-news0.46158595355439              172             1
# NiPea$n|Eu@<@>'L nikp-info0.687953309587529             386             1
#                  nikp-info0.40776251224919             1200             1
# EcFVMmG[En=fe'Jm eckvunway0.0201431029243903            415             1
# EdLkeO%w](R~Za7T myd[anger0.185175614387759             314             1
# NiPea$n|Eu@<@>'L nikolease0.522717681429552              83             1
#                  nikolease0.152433481787525             345             1
# Ét2:1))2]qB2`9;^ etujation0.0817298363167827            870             1
#
#                                               total_customers  total_items  \
# Brand            Product
# Eb@*a7)nz-LaZaH! ebaxpicks0.0962410021889232                1            1
# NiPea$n|Eu@<@>'L nikp-info0.938396305656351                 1            1
# Eb@*a7)nz-LaZaH! ebay-news0.46158595355439                  1            1
# NiPea$n|Eu@<@>'L nikp-info0.687953309587529                 1            1
#                  nikp-info0.40776251224919                  1            1
# EcFVMmG[En=fe'Jm eckvunway0.0201431029243903                1            1
# EdLkeO%w](R~Za7T myd[anger0.185175614387759                 1            1
# NiPea$n|Eu@<@>'L nikolease0.522717681429552                 1            1
#                  nikolease0.152433481787525                 1            1
# Ét2:1))2]qB2`9;^ etujation0.0817298363167827                1            1
#
#                                              Ranking
# Brand            Product
# Eb@*a7)nz-LaZaH! ebaxpicks0.0962410021889232     Low
# NiPea$n|Eu@<@>'L nikp-info0.938396305656351     High
# Eb@*a7)nz-LaZaH! ebay-news0.46158595355439       Low
# NiPea$n|Eu@<@>'L nikp-info0.687953309587529   Medium
#                  nikp-info0.40776251224919      High
# EcFVMmG[En=fe'Jm eckvunway0.0201431029243903  Medium
# EdLkeO%w](R~Za7T myd[anger0.185175614387759      Low
# NiPea$n|Eu@<@>'L nikolease0.522717681429552      Low
#                  nikolease0.152433481787525      Low
# Ét2:1))2]qB2`9;^ etujation0.0817298363167827    High

# %%
items_revenue.reset_index(level=0)
items_revenue.reset_index(inplace=True)

# %%
items_revenue
# Out:
#                   Brand                      Product  total_revenue  \
# 0      !lMifo~0~N65rM}2   skyK-date0.237469692167954           1416
# 1      #B_-`aDe`}CVt'!A   18-`lease0.952310074301681            193
# 2      #B_-`aDe`}CVt'!A  202rvideo0.0198947312483128            312
# 3      #B_-`aDe`}CVt'!A   6layenter0.832904875099387            960
# 4      #B_-`aDe`}CVt'!A   a-cPrants0.941652415797535            638
# ...                 ...                          ...            ...
# 13537  ze\yQP9Ju,s(O|>]   zel`video0.809705577564763            236
# 13538  ze\yQP9Ju,s(O|>]   zelkvideo0.542849205536647            290
# 13539  ze\yQP9Ju,s(O|>]   zeloalbum0.673018009367897           2241
# 13540  Ét2:1))2]qB2`9;^   etua-baby0.472156023137423            292
# 13541  Ét2:1))2]qB2`9;^  etujation0.0817298363167827            870
#
#        total_orders  total_customers  total_items   Ranking
# 0                 3                3            3  Cash Cow
# 1                 1                1            1       Low
# 2                 1                1            1       Low
# 3                 3                3            3      High
# 4                 2                2            2    Medium
# ...             ...              ...          ...       ...
# 13537             1                1            1       Low
# 13538             2                2            2       Low
# 13539             3                3            3  Cash Cow
# 13540             2                2            2       Low
# 13541             1                1            1      High
#
# [13542 rows x 7 columns]

# %%
traffic_details = traffic.groupby(['Date','Product','Brand']).agg(users=('users','sum'),uniquePageviews = ('uniquePageviews','sum'),pageviews = ('pageviews','sum'))

# %%
traffic_details.reset_index(level=0,inplace=True)
traffic_details.reset_index(inplace=True)

# %%
traffic_details
# Out:
#                   Brand                      Product        Date   users  \
# 0      SSJ%#@$7LTf<p'Jx   101Dlease0.745305177696334  2020-01-01   285.4
# 1      MouDd/fn,XEARhBp    a-qXailer0.39660536369098  2020-01-01  3450.4
# 2      MiUNo1$pZkrlcw>M   appMn-usd0.284138838758011  2020-01-01  1447.0
# 3      Ro7|R40![FY$PS`<   artjriner0.183950395687591  2020-01-01  3413.0
# 4      PaasB'\_LlDEk`=W   baiXpsule0.236876019278184  2020-01-01   642.6
# ...                 ...                          ...         ...     ...
# 17884  Mc&v?E*9%}~WP@rD   twiO-word0.109741844099603  2020-12-09   813.2
# 17885  Ty'/0_5dc?P9JKLf  tygboraww0.0915621394874353  2020-12-09  1339.0
# 17886  Vag9"-Z=gN30ND@[   vanAction0.315573410341238  2020-12-09   309.2
# 17887  Vag9"-Z=gN30ND@[  vanMtists0.0499183505700914  2020-12-09  5248.2
# 17888  Relp\+KJ?D,cWw0P   vetssalia0.105184586361579  2020-12-09   287.0
#
#        uniquePageviews  pageviews
# 0                286.6      305.6
# 1               3497.6     3705.8
# 2               1465.6     1562.6
# 3               3469.6     3795.6
# 4                653.8      726.8
# ...                ...        ...
# 17884            831.6      889.8
# 17885           1353.8     1457.6
# 17886            309.6      330.4
# 17887           6364.2    25109.6
# 17888            290.8      305.4
#
# [17889 rows x 6 columns]

# %%
items_traffic = traffic.groupby(['Product','Brand']).agg(users=('users','sum'),uniquePageviews = ('uniquePageviews','sum'),pageviews = ('pageviews','sum'))
items_traffic.reset_index(level=0)
items_traffic.reset_index(inplace=True)

# %%
items_traffic.sort_values('pageviews',ascending=False).head(10)
# Out:
#                           Product                   Brand     users  \
# 14734  sonEies-x0.139039192479287  So)zm5Pl^_G5_x007f_t?q  215222.6
# 12990  porQlease0.507911745358356        Ac8IJsKH,4xtY.Tk  155640.0
# 13199  pumMvideo0.837931992780922        PU]vXmX9fgf$xf!/   47779.6
# 2585   besfeek-50.280274313298435        BajeQM&IzKX.a8&_   53508.2
# 13853  rogLrecap0.644396392507623        LaX{ty9j_zZdD-\`   52381.2
# 7423   jefXaunch0.410067394635876        Stc\9>Cqq;Rn&/|F   43667.4
# 3688   chrL-york0.372865344640649        Ch6hNzXa,'=Q=)Wi   42787.8
# 17535  wradaunch0.370927222684073        Wrv1Qv~}Dk7@']x3   42977.6
# 1382   angztered0.926486710136623        An1a]{mE?nl\sM%&   34073.4
# 6062   goa]akers0.899516668943853  Ai/cV(XG>`JN2L_x007f_n   42587.8
#
#        uniquePageviews  pageviews
# 14734         221108.4   232177.0
# 12990         156789.4   170599.0
# 13199          55759.2   128891.8
# 2585           61120.4   126771.0
# 13853          59658.8   124284.2
# 7423           50536.2   104984.2
# 3688           49496.4   103863.4
# 17535          49637.6   103850.0
# 1382           40323.6    87999.6
# 6062           44467.0    78523.6

# %%
items_traffic.sort_values('pageviews',ascending=False).tail(10)
# Out:
#                             Product             Brand  users  uniquePageviews  \
# 9343     maju-date0.799046146817876  Ma?Mwli9eyEN''@w    2.0              2.0
# 16743    undjcline0.806504582435603  Un3Iq;#h/1zA_`s?    1.4              1.4
# 343      a-cClease0.167928605630817  Ve""8X{n*HPW!bil    1.6              1.6
# 5309   facQ-rise0.00977738420521201  Ap!FulqmT[82a2/E    0.8              0.8
# 17814     yunsement0.44148099082229  Yu%jaXeE/8L$d$yX    0.2              0.2
# 16221    tisetream0.262717438134904  Tir72~+xaqy!(G\-    0.4              0.4
# 2948     bobK-news0.573637665518942  Ac8IJsKH,4xtY.Tk    0.2              0.2
# 15459    sylEemand0.214265914271909  RoQ+;,f@QlJHzNR&    0.4              0.4
# 13446    recPeator0.470956776867346  OlDe}#G)yIt'+Bc3    0.2              0.2
# 1695     ariDcle-20.188973495512866  Ar0eK=K&2^(."ab~    0.2              0.2
#
#        pageviews
# 9343         2.0
# 16743        1.8
# 343          1.6
# 5309         0.8
# 17814        0.6
# 16221        0.4
# 2948         0.4
# 15459        0.4
# 13446        0.4
# 1695         0.4

# %%
items_traffic['pageviews'].describe()
# Out:
# count     17889.000000
# mean       1592.936453
# std        4412.133767
# min           0.400000
# 25%         358.800000
# 50%         683.600000
# 75%        1499.800000
# max      232177.000000
# Name: pageviews, dtype: float64

# %%
items_traffic['Traffic_Ranking']=items_traffic.apply (lambda x: 'Low' if (x['pageviews'] <358 )
                                                            else ('Medium'if (x['pageviews'] > 358 and x['pageviews'] < 683)
                                                            else ('Hight' if (x['pageviews'] > 683 and x['pageviews'] < 1499)
                                                            else 'Most Popular')),axis =1 )

# %%
items_traffic.merge(items_revenue,left_on=['Product','Brand'],right_on= ['Product','Brand'],how='inner').sort_values(['pageviews','total_revenue'],ascending=False)
# Out:
#                           Product             Brand     users  \
# 8723   porQlease0.507911745358356  Ac8IJsKH,4xtY.Tk  155640.0
# 8868   pumMvideo0.837931992780922  PU]vXmX9fgf$xf!/   47779.6
# 1667   besfeek-50.280274313298435  BajeQM&IzKX.a8&_   53508.2
# 9318   rogLrecap0.644396392507623  LaX{ty9j_zZdD-\`   52381.2
# 4880   jefXaunch0.410067394635876  Stc\9>Cqq;Rn&/|F   43667.4
# ...                           ...               ...       ...
# 12017   yunsement0.44148099082229  Yu%jaXeE/8L$d$yX       0.2
# 9037   recPeator0.470956776867346  OlDe}#G)yIt'+Bc3       0.2
# 1893   bobK-news0.573637665518942  Ac8IJsKH,4xtY.Tk       0.2
# 10909  tisetream0.262717438134904  Tir72~+xaqy!(G\-       0.4
# 1109   ariDcle-20.188973495512866  Ar0eK=K&2^(."ab~       0.2
#
#        uniquePageviews  pageviews Traffic_ranking Traffic_Ranking  \
# 8723          156789.4   170599.0    Most Popular    Most Popular
# 8868           55759.2   128891.8    Most Popular    Most Popular
# 1667           61120.4   126771.0    Most Popular    Most Popular
# 9318           59658.8   124284.2    Most Popular    Most Popular
# 4880           50536.2   104984.2    Most Popular    Most Popular
# ...                ...        ...             ...             ...
# 12017              0.2        0.6             Low             Low
# 9037               0.2        0.4             Low             Low
# 1893               0.2        0.4             Low             Low
# 10909              0.4        0.4             Low             Low
# 1109               0.2        0.4             Low             Low
#
#        total_revenue  total_orders  total_customers  total_items   Ranking
# 8723            2292             2                2            2  Cash Cow
# 8868            2829             3                3            3  Cash Cow
# 1667            2482             2                2            2  Cash Cow
# 9318            1114             1                1            1      High
# 4880             160             1                1            1       Low
# ...              ...           ...              ...          ...       ...
# 12017            894             1                1            1      High
# 9037            2096             4                4            4  Cash Cow
# 1893             598             1                1            1    Medium
# 10909            431             1                1            1    Medium
# 1109             171             1                1            1       Low
#
# [12067 rows x 12 columns]

# %%
items_revenue.merge(items_traffic,left_on = ['Product','Brand'],right_on=['Product','Brand'],how = 'inner').sort_values(['total_revenue','pageviews'],ascending=False)
# Out:
#                   Brand                     Product  total_revenue  \
# 4298   Il^(xPdB:S`#irqz  hypsrview0.321288570724117           9072
# 225    Ac8IJsKH,4xtY.Tk  audE-info0.884915261087885           7665
# 8760   Relp\+KJ?D,cWw0P  reeelease0.452821711209563           7119
# 11173  YMbpE$ev3qMx-h*E  ymc_orson0.319251813809483           6810
# 9000   Sa?9zXUH5iJbuE'S   samLement0.78565851365938           6762
# ...                 ...                         ...            ...
# 2786   Di2&2w%Z2_S.BSoW  magE-info0.345398543510131           -555
# 6779   Nes[8ukT8KBR8yVs  news-info0.461919646457777           -600
# 3831   GeYut1YKw^'`D:p&  getz-info0.411473609280735           -663
# 11848  muy(D#"d02`vwt_^  masGtream0.361077670662163           -699
# 741    AiCF)Msmll)aU2_C  stojo-unc0.375966250890653           -735
#
#        total_orders  total_customers  total_items   Ranking   users  \
# 4298              9                9            9  Cash Cow   524.2
# 225               7                7            7  Cash Cow  1086.4
# 8760              7                7            7  Cash Cow   257.8
# 11173             6                6            6  Cash Cow   198.4
# 9000              6                6            6  Cash Cow  1454.6
# ...             ...              ...          ...       ...     ...
# 2786              5                5            5       Low   312.6
# 6779              4                4            4       Low   352.0
# 3831              3                3            3       Low   344.8
# 11848             3                3            3       Low   181.8
# 741               3                3            3       Low  2952.2
#
#        uniquePageviews  pageviews Traffic_ranking Traffic_Ranking
# 4298             539.8      587.0          Medium          Medium
# 225             1110.8     1205.6           Hight           Hight
# 8760             259.2      281.8             Low             Low
# 11173            203.2      223.2             Low             Low
# 9000            1479.2     1590.0    Most Popular    Most Popular
# ...                ...        ...             ...             ...
# 2786             316.8      334.8             Low             Low
# 6779             363.6      394.6          Medium          Medium
# 3831             355.4      383.6          Medium          Medium
# 11848            185.0      193.0             Low             Low
# 741             2994.6     3380.2    Most Popular    Most Popular
#
# [12067 rows x 12 columns]

# %% [markdown]
# Findings => Top Highest revenue products dont have high pageviews

# %%
revenue_popularity = items_revenue.merge(items_traffic,left_on = ['Product','Brand'],right_on=['Product','Brand'],how = 'inner').sort_values(['total_revenue','pageviews'],ascending=False)

# %%
revenue_popularity = revenue_popularity[['Brand','Product','total_revenue','pageviews','Ranking','Traffic_Ranking']]

# %%
revenue_popularity.head(5)
# Out:
#                   Brand                     Product  total_revenue  pageviews  \
# 4298   Il^(xPdB:S`#irqz  hypsrview0.321288570724117           9072      587.0
# 225    Ac8IJsKH,4xtY.Tk  audE-info0.884915261087885           7665     1205.6
# 8760   Relp\+KJ?D,cWw0P  reeelease0.452821711209563           7119      281.8
# 11173  YMbpE$ev3qMx-h*E  ymc_orson0.319251813809483           6810      223.2
# 9000   Sa?9zXUH5iJbuE'S   samLement0.78565851365938           6762     1590.0
#
#         Ranking Traffic_Ranking
# 4298   Cash Cow          Medium
# 225    Cash Cow           Hight
# 8760   Cash Cow             Low
# 11173  Cash Cow             Low
# 9000   Cash Cow    Most Popular

# %%
pd.DataFrame(revenue_popularity.groupby(['Ranking','Traffic_Ranking'])['Ranking'].count())
# Out:
#                           Ranking
# Ranking  Traffic_Ranking
# Cash Cow Hight                745
#          Low                  775
#          Medium               775
#          Most Popular         738
# High     Hight                727
#          Low                  756
#          Medium               762
#          Most Popular         797
# Low      Hight                784
#          Low                  747
#          Medium               723
#          Most Popular         731
# Medium   Hight                772
#          Low                  746
#          Medium               774
#          Most Popular         715

# %% [markdown]
# => This is a very evenly distributed dataset , so it could affect the results

# %%
revenue_popularity[(revenue_popularity['Traffic_Ranking'] == 'Most Popular') & (revenue_popularity['Ranking'] == 'Cash Cow')].sort_values(['total_revenue','pageviews'],ascending=False).head(5)
# Out:
#                  Brand                     Product  total_revenue  pageviews  \
# 9000  Sa?9zXUH5iJbuE'S   samLement0.78565851365938           6762     1590.0
# 8666  Relp\+KJ?D,cWw0P  bbcF-date0.977769785530841           6455     2049.6
# 4816  Ka>n{\}.q.~P&*Ao  takgeveal0.557457939403364           6454     8596.2
# 8407  PoAqnL=>P9Qb"ZUa  poryn-9920.309751616966229           6315    10795.6
# 6948  NiPea$n|Eu@<@>'L  g-dX-look0.897569041695992           6145     2588.0
#
#        Ranking Traffic_Ranking
# 9000  Cash Cow    Most Popular
# 8666  Cash Cow    Most Popular
# 4816  Cash Cow    Most Popular
# 8407  Cash Cow    Most Popular
# 6948  Cash Cow    Most Popular

# %%
revenue_popularity[(revenue_popularity['Traffic_Ranking'] == 'Low') & (revenue_popularity['Ranking'] == 'Cash Cow')].sort_values(['total_revenue','pageviews'],ascending=False).head(5)
# Out:
#                   Brand                       Product  total_revenue  \
# 8760   Relp\+KJ?D,cWw0P    reeelease0.452821711209563           7119
# 11173  YMbpE$ev3qMx-h*E    ymc_orson0.319251813809483           6810
# 5972   Mi+QB'FqF;cGT)Y'    theftream0.650769488105747           6575
# 3211   Exa~e4sZi*|fpD<^    ausDition0.316805159126848           5336
# 4963   Ki2W*dzo0^'?Jr-"  run_video0.00393012917991042           5322
#
#        pageviews   Ranking Traffic_Ranking
# 8760       281.8  Cash Cow             Low
# 11173      223.2  Cash Cow             Low
# 5972       350.2  Cash Cow             Low
# 3211       161.4  Cash Cow             Low
# 4963       290.6  Cash Cow             Low

# %%
revenue_popularity[(revenue_popularity['Traffic_Ranking'] == 'Most Popular') & (revenue_popularity['Ranking'] == 'Low')].sort_values(['total_revenue','pageviews'],ascending=False).head(5)
# Out:
#                   Brand                       Product  total_revenue  \
# 9778   TN~2zg4|A-y2vih~    snofailer0.725276401832327            350
# 11566  ad(;%f6iD'}9EHD[    phak-look0.477724180992789            349
# 6265   MouDd/fn,XEARhBp   newD-20200.0182418730571077            349
# 5627   Ma/J0*ar?Rce}C(@    macNideos0.505902918232793            349
# 10922  WHh2aol.(?D1=4y%  whoBables0.00927985090738437            348
#
#        pageviews Ranking Traffic_Ranking
# 9778      1782.6     Low    Most Popular
# 11566     3972.8     Low    Most Popular
# 6265      2024.6     Low    Most Popular
# 5627      1661.4     Low    Most Popular
# 10922    77737.0     Low    Most Popular

# %% [markdown]
# <b> Customer Segmentation <b>

# %%
customer_info.head(5)
# Out:
#                 FirstName               LastName              Country  \
# ID
# 0      V0.296680287495188     L0.104646531512644          FR - France
# 1      D0.793097101838541   Law0.141693355411763        GER - Germany
# 2    Ker0.141418247925814    Ng0.753960335680345          FR - France
# 3    Fik0.950054552966336     F0.590961171612745  UK - United Kingdom
# 4   Iona0.294287981536498  Ison0.826191754811968           IT - Italy
#
#    DateJoined Gender   Birthday Newsletter
# ID
# 0  2015-12-18    NaN 1968-02-03          N
# 1  2015-12-21      M 2009-10-06          Y
# 2  2015-12-22      F 1990-08-04          Y
# 3  2015-12-22      M 1974-07-24          N
# 4  2015-12-22      M 1981-08-13          N

# %%
customer_info.shape
# Out:
# (770, 7)

# %%
result.head(5)
# Out:
#    OrderID  CustomerID  ItemID TransactionDate   Channel  \
# 0        0           0     352      2020-03-21  In Store
# 1      637          57     352      2020-03-15  In Store
# 2        0           0    3433      2020-07-14  In Store
# 3     1840         167    3433      2020-05-16  In Store
# 4     3386         307    3433      2020-04-23  In Store
#
#                FirstName                LastName              Country  \
# 0     V0.296680287495188      L0.104646531512644          FR - France
# 1  Var0.0876970591979241  Bhan0.0592432181453122        GER - Germany
# 2     V0.296680287495188      L0.104646531512644          FR - France
# 3     Y0.694526245425698    Pur0.889218979929135  UK - United Kingdom
# 4   Moh0.478682882191102  Khair0.475794987205303          FR - France
#
#   DateJoined Gender   Birthday Newsletter                     Product  \
# 0 2015-12-18    NaN 1968-02-03          N  chrUrumor0.784919078952733
# 1 2016-02-02      F 1966-01-14          N  chrUrumor0.784919078952733
# 2 2015-12-18    NaN 1968-02-03          N  corGvideo0.268391324982493
# 3 2015-04-16      M 1972-03-23          Y  corGvideo0.268391324982493
# 4 2016-06-02    NaN 1989-05-04          Y  corGvideo0.268391324982493
#
#               Brand  SellPrice  CostPrice  revenue
# 0  MouDd/fn,XEARhBp        735        426      309
# 1  MouDd/fn,XEARhBp        735        426      309
# 2  muy(D#"d02`vwt_^        963        491      472
# 3  muy(D#"d02`vwt_^        963        491      472
# 4  muy(D#"d02`vwt_^        963        491      472

# %%
customer_summary = result.groupby('CustomerID').agg(total_orders=('OrderID','count'),total_revenue = ('revenue','sum'))

# %%
customer_summary.reset_index(inplace=True)

# %%
customer_summary.head(5)
# Out:
#    CustomerID  total_orders  total_revenue
# 0           0            45          21999
# 1           1            39          24976
# 2           2            21          12399
# 3           3            19           9492
# 4           4            48          25137

# %%
customer_data = customer_info.merge(customer_summary,left_on = 'ID',right_on = 'CustomerID',how = 'inner')

# %%
customer_data
# Out:
#                  FirstName                LastName              Country  \
# 0       V0.296680287495188      L0.104646531512644          FR - France
# 1       D0.793097101838541    Law0.141693355411763        GER - Germany
# 2     Ker0.141418247925814     Ng0.753960335680345          FR - France
# 3     Fik0.950054552966336      F0.590961171612745  UK - United Kingdom
# 4    Iona0.294287981536498   Ison0.826191754811968           IT - Italy
# ..                     ...                     ...                  ...
# 765    Ya0.945566148422846     Lo0.214781069325519        GER - Germany
# 766   Yoo0.331072249620266    Low0.870500054610635        GER - Germany
# 767    Za0.957577858135873  Thoma0.729674423009536        GER - Germany
# 768     Y0.286774649994125   Aung0.752567424443609        GER - Germany
# 769    Yu0.868816854574661   Tuck0.670377392941702        GER - Germany
#
#     DateJoined Gender   Birthday Newsletter  CustomerID  total_orders  \
# 0   2015-12-18    NaN 1968-02-03          N           0            45
# 1   2015-12-21      M 2009-10-06          Y           1            39
# 2   2015-12-22      F 1990-08-04          Y           2            21
# 3   2015-12-22      M 1974-07-24          N           3            19
# 4   2015-12-22      M 1981-08-13          N           4            48
# ..         ...    ...        ...        ...         ...           ...
# 765 2016-09-05      F 1989-10-25          N         765            38
# 766 2016-09-05    NaN 1965-07-25          Y         766             7
# 767 2016-09-05      M 1980-11-07          Y         767            57
# 768 2016-09-05      M 1980-09-17          Y         768            49
# 769 2016-09-05      M 1990-05-23          Y         769            31
#
#      total_revenue
# 0            21999
# 1            24976
# 2            12399
# 3             9492
# 4            25137
# ..             ...
# 765          20151
# 766           3487
# 767          31652
# 768          21258
# 769          15501
#
# [770 rows x 10 columns]

# %%
customer_data = customer_data[['CustomerID','Country','DateJoined','Gender','Birthday','Newsletter','total_orders','total_revenue']]

# %%
customer_data.dtypes
# Out:
# CustomerID                int64
# Country                  object
# DateJoined       datetime64[ns]
# Gender                   object
# Birthday         datetime64[ns]
# Newsletter               object
# total_orders              int64
# total_revenue             int64
# dtype: object

# %%
import datetime

# %%
customer_data['Age']=''
i = 0
for i in range(len(customer_data)):
    customer_data['Age'][i]= datetime.date.today().year - datetime.datetime.date(customer_data['Birthday'][i]).year
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_7180\1714314703.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_data['Age']=''
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_7180\1714314703.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_data['Age'][i]= datetime.date.today().year - datetime.datetime.date(customer_data['Birthday'][i]).year

# %%
customer_data
# Out:
#      CustomerID              Country DateJoined Gender   Birthday Newsletter  \
# 0             0          FR - France 2015-12-18    NaN 1968-02-03          N
# 1             1        GER - Germany 2015-12-21      M 2009-10-06          Y
# 2             2          FR - France 2015-12-22      F 1990-08-04          Y
# 3             3  UK - United Kingdom 2015-12-22      M 1974-07-24          N
# 4             4           IT - Italy 2015-12-22      M 1981-08-13          N
# ..          ...                  ...        ...    ...        ...        ...
# 765         765        GER - Germany 2016-09-05      F 1989-10-25          N
# 766         766        GER - Germany 2016-09-05    NaN 1965-07-25          Y
# 767         767        GER - Germany 2016-09-05      M 1980-11-07          Y
# 768         768        GER - Germany 2016-09-05      M 1980-09-17          Y
# 769         769        GER - Germany 2016-09-05      M 1990-05-23          Y
#
#      total_orders  total_revenue Age
# 0              45          21999  55
# 1              39          24976  14
# 2              21          12399  33
# 3              19           9492  49
# 4              48          25137  42
# ..            ...            ...  ..
# 765            38          20151  34
# 766             7           3487  58
# 767            57          31652  43
# 768            49          21258  43
# 769            31          15501  33
#
# [770 rows x 9 columns]

# %%
customer_data['Loyalty'] = ''
i = 0 
for i in range(len(customer_data)):
    customer_data['Loyalty'][i] = datetime.date.today().year - datetime.datetime.date(customer_data['DateJoined'][i]).year
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_7180\1549870997.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   customer_data['Loyalty'][i] = datetime.date.today().year - datetime.datetime.date(customer_data['DateJoined'][i]).year

# %%
customer_data['Loyalty'].unique()
# Out:
# array([8, 7], dtype=object)

# %%
customer_data['Country'].unique()
# Out:
# array(['FR - France', 'GER - Germany', 'UK - United Kingdom',
#        'IT - Italy'], dtype=object)

# %%
customer_data['Age'] = customer_data['Age'].astype('int')

# %%
customer_data['Age'].plot(kind='hist')
# Out:
# <Axes: ylabel='Frequency'>

# %%
sns.boxplot(y=customer_data['Age'])
# Out:
# <Axes: ylabel='Age'>

# %%
customer_data['Age'].describe()
# Out:
# count    770.000000
# mean      34.877922
# std       13.035040
# min       13.000000
# 25%       24.000000
# 50%       34.000000
# 75%       45.000000
# max       58.000000
# Name: Age, dtype: float64

# %%
customer_data['Age'].value_counts()
# Out:
# 24    25
# 32    24
# 28    23
# 20    22
# 34    21
# 40    21
# 25    21
# 30    20
# 42    20
# 41    20
# 33    19
# 39    19
# 53    19
# 17    19
# 57    19
# 37    18
# 38    18
# 22    18
# 45    18
# 26    17
# 58    17
# 14    17
# 43    17
# 16    17
# 15    17
# 18    16
# 51    16
# 19    15
# 35    15
# 49    15
# 50    14
# 21    14
# 55    14
# 52    14
# 13    14
# 23    14
# 27    13
# 54    13
# 47    13
# 44    13
# 31    12
# 56    12
# 46    12
# 36    12
# 48    12
# 29    11
# Name: Age, dtype: int64

# %%
customer_data.fillna("Unknown",inplace=True)

# %%
customer_data['Gender'].value_counts()
# Out:
# F          262
# M          257
# Unknown    251
# Name: Gender, dtype: int64

# %%
customer_data['Country'].value_counts()
# Out:
# GER - Germany          321
# FR - France            256
# IT - Italy             128
# UK - United Kingdom     65
# Name: Country, dtype: int64

# %%
customer_data['Newsletter'].value_counts()
# Out:
# Y    413
# N    357
# Name: Newsletter, dtype: int64

# %%
customer_data['Loyalty'].value_counts()
# Out:
# 7    607
# 8    163
# Name: Loyalty, dtype: int64

# %%
customer_data.groupby(['Country'])['total_revenue'].sum()
# Out:
# Country
# FR - France            4489379
# GER - Germany          5738521
# IT - Italy             2176787
# UK - United Kingdom    1236838
# Name: total_revenue, dtype: int64

# %%
customer_data.groupby(['Loyalty','Gender'])['Loyalty'].count()
# Out:
# Loyalty  Gender
# 7        F          203
#          M          203
#          Unknown    201
# 8        F           59
#          M           54
#          Unknown     50
# Name: Loyalty, dtype: int64

# %%
customer_data['total_revenue'].describe()
# Out:
# count      770.000000
# mean     17716.266234
# std       9226.234431
# min        422.000000
# 25%      10003.250000
# 50%      17669.000000
# 75%      24753.500000
# max      45143.000000
# Name: total_revenue, dtype: float64

# %%
customer_data['Monetary'] = customer_data.apply(lambda x: '1' if (x['total_revenue'] < 10003) 
                                   else ('2' if (x['total_revenue'] >= 10003 and x['total_revenue'] < 17669) 
                                         else ('3' if (x['total_revenue'] >= 17669 and x['total_revenue'] < 24753) 
                                               else '4')), axis = 1)

# %%
customer_data['Youth'] = customer_data.apply(lambda x: '1' if (x['Age'] < 24) 
                                   else ('2' if (x['Age'] >= 24 and x['Age'] < 34) 
                                         else ('3' if (x['Age'] >= 34 and x['Age'] < 45) 
                                               else '4')), axis = 1)

# %%
df = customer_data[['Loyalty','Monetary','Youth']]

# %% [markdown]
# <b> Using Machine Learning to Clustering <b>

# %%
pip install kneed
# Out:
# Collecting kneed
#   Downloading kneed-0.8.3-py3-none-any.whl (10 kB)
# Requirement already satisfied: numpy>=1.14.2 in c:\users\admin\lib\site-packages (from kneed) (1.24.2)
# Requirement already satisfied: scipy>=1.0.0 in c:\users\admin\lib\site-packages (from kneed) (1.10.1)
# Installing collected packages: kneed
# Successfully installed kneed-0.8.3
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.cluster import KMeans
from kneed import KneeLocator

# %%
kmeans = KMeans(init="random",n_clusters=3,n_init=10,max_iter=300,random_state=42)

# %%
kmeans.fit(df)
# Out:
# KMeans(init='random', n_clusters=3, n_init=10, random_state=42)

# %%
kmeans_kwargs = {"init": "random","n_init": 10,"max_iter": 300,"random_state": 42}
  
sse = []
for k in range(1, 11):
    kmeans = KMeans(n_clusters=k, **kmeans_kwargs)
    kmeans.fit(df)
    sse.append(kmeans.inertia_)

# %%
plt.style.use("fivethirtyeight")
plt.plot(range(1, 11), sse)
plt.xticks(range(1, 11))
plt.xlabel("Number of Clusters")
plt.ylabel("SSE")
plt.show()

# %%
kl = KneeLocator(range(1, 11), sse, curve="convex", direction="decreasing")

# %%
kl.elbow
# Out:
# 4

# %% [markdown]
# => There are 4 clusters, which means there are 4 customer segments

# %%
nclusters = 4
kmeans = KMeans(n_clusters=nclusters, random_state=0).fit(df)
# Out:
# c:\Users\ADMIN\Lib\site-packages\sklearn\cluster\_kmeans.py:870: FutureWarning: The default value of `n_init` will change from 10 to 'auto' in 1.4. Set the value of `n_init` explicitly to suppress the warning
#   warnings.warn(

# %%
df["Cluster Labels"] = kmeans.labels_
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_7180\1365365962.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df["Cluster Labels"] = kmeans.labels_

# %%
df
# Out:
#      Loyalty Monetary Youth  Cluster Labels
# 0          8        3     4               2
# 1          8        4     1               3
# 2          8        2     2               0
# 3          8        1     4               1
# 4          8        4     3               2
# ..       ...      ...   ...             ...
# 765        7        3     3               2
# 766        7        1     4               1
# 767        7        4     3               2
# 768        7        3     3               2
# 769        7        2     2               0
#
# [770 rows x 4 columns]

# %%
customer_data["Cluster Labels"] = kmeans.labels_

# %%
#Cluster 1

# %%
customer_data[customer_data["Cluster Labels"] == 0]
# Out:
#      CustomerID              Country DateJoined   Gender   Birthday  \
# 2             2          FR - France 2015-12-22        F 1990-08-04
# 8             8          FR - France 2015-12-28        M 1991-02-28
# 13           13           IT - Italy 2016-01-05        F 2003-03-16
# 14           14           IT - Italy 2016-01-05        M 2006-10-25
# 15           15        GER - Germany 2016-01-06        F 1997-11-24
# ..          ...                  ...        ...      ...        ...
# 754         754        GER - Germany 2016-09-05        M 2006-05-22
# 762         762        GER - Germany 2016-09-05        M 2010-08-23
# 763         763        GER - Germany 2015-05-25  Unknown 2007-02-04
# 764         764  UK - United Kingdom 2015-05-25        M 1995-04-02
# 769         769        GER - Germany 2016-09-05        M 1990-05-23
#
#     Newsletter  total_orders  total_revenue  Age  Loyalty Monetary Youth  \
# 2            Y            21          12399   33        8        2     2
# 8            Y            25          15966   32        8        2     2
# 13           N            20          10550   20        7        2     1
# 14           N            10           5801   17        7        1     1
# 15           Y            32          15799   26        7        2     2
# ..         ...           ...            ...  ...      ...      ...   ...
# 754          Y            19          11634   17        7        2     1
# 762          N            32          12329   13        7        2     1
# 763          N            30          12527   16        8        2     1
# 764          Y             6           3650   28        8        1     2
# 769          Y            31          15501   33        7        2     2
#
#      Cluster Labels
# 2                 0
# 8                 0
# 13                0
# 14                0
# 15                0
# ..              ...
# 754               0
# 762               0
# 763               0
# 764               0
# 769               0
#
# [191 rows x 13 columns]

# %%
#Cluster 2
customer_data[customer_data["Cluster Labels"] == 1]
# Out:
#      CustomerID              Country DateJoined   Gender   Birthday  \
# 3             3  UK - United Kingdom 2015-12-22        M 1974-07-24
# 7             7        GER - Germany 2015-12-24        F 1970-11-12
# 11           11           IT - Italy 2015-04-01        F 1987-10-20
# 27           27          FR - France 2016-01-13  Unknown 1981-06-04
# 30           30  UK - United Kingdom 2016-01-14  Unknown 1986-06-15
# ..          ...                  ...        ...      ...        ...
# 745         745        GER - Germany 2016-09-05        M 1983-12-11
# 748         748        GER - Germany 2016-09-05        F 1966-09-24
# 756         756        GER - Germany 2016-09-05        M 1985-03-25
# 759         759        GER - Germany 2016-09-05  Unknown 1984-07-25
# 766         766        GER - Germany 2016-09-05  Unknown 1965-07-25
#
#     Newsletter  total_orders  total_revenue  Age  Loyalty Monetary Youth  \
# 3            N            19           9492   49        8        1     4
# 7            Y            19           8895   53        8        1     4
# 11           N            21          11623   36        8        2     3
# 27           Y            29          11932   42        7        2     3
# 30           Y            27          14435   37        7        2     3
# ..         ...           ...            ...  ...      ...      ...   ...
# 745          N            18           7967   40        7        1     3
# 748          Y            16          10680   57        7        2     4
# 756          N            19          11297   38        7        2     3
# 759          N            15           4543   39        7        1     3
# 766          Y             7           3487   58        7        1     4
#
#      Cluster Labels
# 3                 1
# 7                 1
# 11                1
# 27                1
# 30                1
# ..              ...
# 745               1
# 748               1
# 756               1
# 759               1
# 766               1
#
# [194 rows x 13 columns]

# %%
#Cluster 3
customer_data[customer_data["Cluster Labels"] == 2]
# Out:
#      CustomerID        Country DateJoined   Gender   Birthday Newsletter  \
# 0             0    FR - France 2015-12-18  Unknown 1968-02-03          N
# 4             4     IT - Italy 2015-12-22        M 1981-08-13          N
# 5             5  GER - Germany 2015-12-23        F 1979-03-27          Y
# 6             6  GER - Germany 2015-12-23        M 1984-06-01          N
# 9             9    FR - France 2015-04-01  Unknown 1984-02-14          Y
# ..          ...            ...        ...      ...        ...        ...
# 760         760  GER - Germany 2016-09-05  Unknown 1972-06-09          N
# 761         761  GER - Germany 2016-09-05  Unknown 1977-11-11          N
# 765         765  GER - Germany 2016-09-05        F 1989-10-25          N
# 767         767  GER - Germany 2016-09-05        M 1980-11-07          Y
# 768         768  GER - Germany 2016-09-05        M 1980-09-17          Y
#
#      total_orders  total_revenue  Age  Loyalty Monetary Youth  Cluster Labels
# 0              45          21999   55        8        3     4               2
# 4              48          25137   42        8        4     3               2
# 5              47          23180   44        8        3     3               2
# 6              28          17967   39        8        3     3               2
# 9              45          24467   39        8        3     3               2
# ..            ...            ...  ...      ...      ...   ...             ...
# 760            54          29565   51        7        4     4               2
# 761            52          30309   46        7        4     4               2
# 765            38          20151   34        7        3     3               2
# 767            57          31652   43        7        4     3               2
# 768            49          21258   43        7        3     3               2
#
# [208 rows x 13 columns]

# %%
#Cluster 4
customer_data[customer_data["Cluster Labels"] == 3]
# Out:
#      CustomerID        Country DateJoined   Gender   Birthday Newsletter  \
# 1             1  GER - Germany 2015-12-21        M 2009-10-06          Y
# 19           19    FR - France 2016-01-07  Unknown 2003-07-06          Y
# 20           20    FR - France 2016-01-08        F 1991-04-19          N
# 23           23     IT - Italy 2016-01-12        F 2000-02-07          N
# 26           26     IT - Italy 2016-01-13  Unknown 2005-01-10          N
# ..          ...            ...        ...      ...        ...        ...
# 740         740  GER - Germany 2016-09-05  Unknown 1998-02-15          Y
# 743         743  GER - Germany 2016-09-05  Unknown 2007-07-23          Y
# 747         747  GER - Germany 2016-09-05        M 2009-02-20          N
# 755         755  GER - Germany 2016-09-05        M 2002-02-17          Y
# 757         757  GER - Germany 2016-09-05        F 1998-10-03          Y
#
#      total_orders  total_revenue  Age  Loyalty Monetary Youth  Cluster Labels
# 1              39          24976   14        8        4     1               3
# 19             36          22198   20        7        3     1               3
# 20             46          23989   32        7        3     2               3
# 23             47          26456   23        7        4     1               3
# 26             55          27746   18        7        4     1               3
# ..            ...            ...  ...      ...      ...   ...             ...
# 740            42          24437   25        7        3     2               3
# 743            58          33172   16        7        4     1               3
# 747            51          27162   14        7        4     1               3
# 755            49          25550   21        7        4     1               3
# 757            52          27168   25        7        4     2               3
#
# [177 rows x 13 columns]

# %%
customer_data['Cluster Labels'].value_counts()
# Out:
# 2    208
# 1    194
# 0    191
# 3    177
# Name: Cluster Labels, dtype: int64

# %% [markdown]
# => It can be seen that KMeans really divide the customers equally

# %% [markdown]
# Cluster 0 are juniors from age 13 - 34 who dont spend much <br>
# Cluster 1 are juniors from age 34 - 58 who dont spend much <br>
# Cluster 2 are seniors from age 34 - 58 who spend much <br>
# Cluster 3 are seniors from age 13 - 34 who spend much
